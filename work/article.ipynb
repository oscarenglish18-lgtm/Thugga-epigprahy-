# %% [markdown]
# # Applying Corpus-Lingusitics to study Commemorative Variation in the Roman World: The Case of Thugga/Dougga

# %% [markdown]
#  ### Author 1[![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID)
# Institution

# %% [markdown]
# ### Author 2 [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/ORCID_ID_IF_EXIST)
# Institution

# %% [markdown]
# [![cc-by](https://licensebuttons.net/l/by/4.0/88x31.png)](https://creativecommons.org/licenses/by/4.0/)
# ©<University of Southampton. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# [![cc-by-nc-nd](https://licensebuttons.net/l/by-nc-nd/4.0/88x31.png)](https://creativecommons.org/licenses/by-nc-nd/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/4.0/)

# %% [markdown]
#  (optional) This article was orginally published (...)

# %% [markdown]
# FirstKeyword, SecondKeyword, AlwaysSeparatedByAComma

# %% [markdown]
# The funerary epigraphy of Thugga (Dougga), Roman North Africa, is characterised by an unusual reliance on a limited range of formulae. This dissertation investigates to which extent this is statistically real by applying a corpus linguistic methodology to assess standardisation metrics at Thugga, Uchi Maius, Thibursicum Bure, Lambaesis and Rome. This comparative analysis involves 6,128 funerary inscriptions drawn from the Epigraphik-Datenbank Clauss-Slaby (EDCS) and compiled with a custom-built Python tool. Multiple standardisation metrics and other data extracted from these corpora point to the existence of unique commemorative preferences at Thugga, potentially related to a local interpretation of the Manes and a conception of obligatory pietas. In doing so, this research sheds light on the complex and localised religious environment of Roman North Africa, in which pre-existing Numidian chthonic traditions and incoming Roman spiritual practices were actively renegotiated rather than simply replaced or assimilated.

# %% [markdown]
# ## Introduction

# %% [markdown]
# North Africa and the Maghreb possess a rich archaeological record, and the study of epigraphy has dominated scholarship in the region (Mattingly and Hitchner, 1995:166-169). The region has long existed as a cultural crossroad, which is reflected in its tradition of diverse commemorative practices (Stone and Stirling, 2007:7). This is a legacy that can be traced long before the Roman occupation. The indigenous Berber population seems to have inhabited the region from at least 7000 BCE (Brett and Fentress, 1996:12) and frequently interacted with the wider Mediterranean world, with tombs morphologically similar to those produced by the Berber people found in Sicily, potentially reflective of this interconnectivity (Brett and Fentress, 1996:16). The Berbers were not necessarily a single coherent culture or identity and encompassed a diverse variety of traditions (Mattingly, 2019:26). Several of these would synthesize into a number of kingdoms, collectively labelled as “Numidians” by the recently arrived Phoenicians (Brett and Fentress, 1996:4).
#
# By the 9th-10th centuries BCE urbanism had emerged indigenously, even deep into the desert (Fentress and Dufton, 2022:174). Although this coincided with the foundation of Carthage, it appears that Mediterranean influences did not replace local cultural and spiritual practices, with a degree of continuity persisting (Mattingly, 2019:18). Nonetheless, Punic influence extended far beyond the political control of Carthage (Brett and Fentress, 1996:24) creating a complex cultural environment. Several of these local cultures produced elaborate funerary traditions (Brett and Fentress, 1996:24).  The transformation of the region into a Roman province was iterative, beginning after the destruction of Carthage and annexation of Punic territory in 146 BCE, a border being delineated between the new Roman province of Africa Vetus and the Numidian Kingdom 90km inland (Hobson, 2022:103). By 43 BCE, the remaining Numidian lands were annexed following a Caesarean victory in the civil war, as a consequence of Numidian support for Pompey. This year also saw the refoundation of Carthage with Roman colonists, alongside the arrival of Roman settler communities to many pre-existing towns (Hobson, 2022:103). One such town was Thugga, a former Numidian centre and presently one of the best-preserved examples of a small Roman town in North Africa (UNESCO, 2026).
#
# In February 2025 I visited Thugga myself whilst travelling in Tunisia and was struck by a pattern in its funerary epigraphy. Nearly every epitaph I examined consisted of the same small cluster of abbreviations, a name, and an age at death. Not only were they extremely short, many deployed virtually identical formulae. They were each devoid of any reference to profession, personal narrative or elaboration. A subsequent survey of the Epigraphik-Datenbank Clauss-Slaby (EDCS), an online repository holding over two thousand funerary inscriptions from the site, confirmed this impression at scale. Thugga's funerary corpus appeared abbreviated, rigid, and almost entirely stripped of individual secular or personal content. This raised an immediate question, whether and to what extent this pattern was statistically real, how it compared to other sites in Roman North Africa, and what the implications of this mean for commemorative culture in the region. This unusual profile has been noted before, Bennett identified Thugga's anomalous reliance on a restricted formulaic register in a macro-level analysis of over 100,000 Roman epitaphs as part of a PhD thesis, attributing it to copybook stonemasons, but explicitly called for more detailed future research (Bennett, 2020:194).
#
# Rather than the copybook template hypothesis, this dissertation will argue that a synthesis of the evidence points to a deliberate commemorative preference for unusual formulae and standardisation at Thugga, likely related to a localist interpretation of the Roman Manes and a conception of ritual correctness related to the completion of obligatory pietas. To demonstrate this, the dissertation applies corpus-linguistic methodology and software to complete a comparative analysis of funerary epigraphy across five sites in Roman North Africa and Rome using 6128 unique inscriptions. These were drawn from the Epigraphik-Datenbank Clauss-Slaby (EDCS) and processed using EDCS CorpusBuilder, a custom-built Python tool developed for this research, which automates the cleaning, preparation and generation of epigraphic corpora. The results of this research shed light on the complicated bilateral religious environment of Roman North Africa which saw aspects of localist and Roman spirituality reinterpreted in a new imperial context.

# %% [markdown]
# ## Historiography, The Manes, Commemoration and Spirituality in Roman North Africa

# %% [markdown]
# Roman annexation did not simply impose a new religious order on North Africa. Evidence points to a process of reinterpretation in which pre-existing spiritual traditions and incoming Roman ones were renegotiated within precise local contexts. Spirituality and commemorative culture are typically interlinked and thus must be assessed together (Scarre, 2011:9). Additionally, it is important to address outdated interpretative frameworks that were once dominant in North African Roman scholarship which can ultimately be traced to colonial rule in the region.

# %% [markdown]
# ### Colonial Archaeology and Spirituality in Roman Africa

# %% [markdown]
# The study of Roman North Africa was fundamentally shaped by the environment it emerged, largely as a legitimising tool for European colonial rulers. France and Italy sought to portray themselves as the inheritors of a Roman European legacy and used archaeology to draw explicit comparisons between themselves and the Roman Empire (Mattingly, 2024:760). One of the consequences of this historiographical agenda was the prioritisation of Latin Epigraphy (McCarty, 2024:8), something as conceived of as evidence of Roman cultural imposition on the region (Hitchner, 2022:4). On the other hand, the pre-Roman period was correspondingly neglected and remains understudied (Mattingly, 2024:761). This ultimately led to the development of an interpretive framework built around a concept of “Romanisation” as an assumed process in which either the pre-existing North Africa population was unilaterally assimilated into Roman culture, or in which a thin Roman veneer was placed over pre-existing traditions, evidenced by indigenous participation in the Latin language and in “Roman” cultural and religious life. (Hitchner, 2022:4 and McCarty, 2024:6). Underpinning this conception was a 3-way ethnic division of the population, into “Punic”, “African” and “Roman” categories, which were considered to be religiously and culturally coherent (Fentress, 1978:507). In reality, these categories only “exist in discourse” (McCarty, 2022:286), identity in Roman North Africa was constantly renegotiated, and neat lines of delineation along an ethnic basis cannot be drawn in a region as diverse as Roman North Africa (McCarty, 2022:286). In Roman North Africa, identity depended less on cultural or ethnic origin, and more on status, wealth, location, employment and religion (Mattingly, 2010:242).
#
# Following decolonisation and the emergence of post-colonial scholarship, the concept of Romanisation was initially flipped rather than dismantled. Marcel Benabou’s La résistance africaine à la Romanisation (1976) constructed a counter-narrative of eternal indigenous resistance to the Roman occupation (Hitchner, 2022:6), but this still posited the existence of monolithic African and Roman culture, existing in binary opposition to one another. In reality North Africa was highly religiously and culturally diverse, host to a patchwork of variable spiritual traditions whose patterns should not be explained by cultural difference but examined within precise local contexts (McCarty, 2022:286). Although this diversity persisted into the Roman period, attempts to explain the ‘peculiarities’ of religion in Roman North Africa, such as the unusual popularity of Saturn by assuming that they represent the continued worship of a pre-Roman god (in the case of Saturn-Baal Hammon) (Cadotte, 2006) are inaccurate (McCarty, 2022:286). North Africa was highly interconnected, to the extent that Roman rule itself was preceded by the arrival of Greco-Roman gods, with an interpretation of Pluto arriving in the Punic period (Cadotte, 2006). This notion of direct continuity is problematic, as in the Roman world, religious and non-religious behaviour were not clearly distinguished (Hingley, 2011:747). The idea of straightforward religious continuity in the context of radical disruption caused by Roman annexation, the destruction of Carthage and the introduction of a Roman citizen Pagus to at least 8 pre-existing towns (Fentress, 2021:965) is not plausible. This radical disruption ultimately led to a reinterpretation and the reshaping of old gods and practices, adapted for new and changing social frameworks (McCarty, 2022:289-296).
#
# Although the Romans were practitioners of Interpretatio Romana, a process in which a foreign god would be integrated or identified with a pre-existing member of the Roman pantheon, this was rarely straightforward transliteration (Ando, 2008:43). The process of this identification was not standardised or regulated and instead was one part of what was typically a complex cultural negotiation and dialogue (Ando, 2008:52). The non-dogmatic nature of Greco-Roman religion allowed for and accommodated simultaneous conflicting interpretations of the same gods. There was often substantial overlap in the jurisdiction of different gods, and complicating things further was the fact that the same god would often be known by multiple different names (Ferrero and Tridimas, 2018:162). This non-dogmatic nature allows for theoretically enormous diversity in practice and conception (King, 2020:86). Additionally, this non-dogmatism allows for the reimagination or reinvention of aspects of the divine. Such a process may have occurred in early Roman North Africa, as indicated by an unusual boom in Tophet construction that appears to have occurred in the aftermath of the destruction of Carthage (McCarty, 2017:398). Unlike typical Carthaginian examples however, the crescent that decorates these Tophets is inverted, and contents used for molk burnings differ significantly, with one example consisting entirely of plant matter, rather than infants or animal sacrifices (McCarty, 2017:405). This is not an example of Carthaginian continuity, but rather reimagination (McCarty, 2017).  This process of re-interpretation was assisted by the Roman tradition of assuming the existence of place-based, unknown deities to the extent that they would petition them generically as “gods of this place” when unsure (Ando, 2008:128). Roman settler participation in pre-existing local traditions is evidenced (Gilhaus, 2021:172).  The religious environment of Early Roman North Africa was one defined by both the introduction of the new and a reimagination of the old, not one of direct continuity nor replacement.

# %% [markdown]
# North Africa presented a patchwork of loosely related deities and place-based spirituality that did not constitute a codified religion, and this was not nullified by Roman annexation (Brett and Fentress, 1996:35-49). There appears to have also been a level of geographic divergence between the coastal belt and interior, defined by the dominance of chthonic cults in former Numidian lands (Mattingly, 2024:773) in which Thugga itself lies. Evidence for this chthonic tradition can be found in the city, which hosted a temple to the deified Numidian king Massinissa (McCarty, 2022:289). An outdated model of Romanization has frequently been applied to Thugga, particularly surrounding the arrival of the Pagus, but also when assessing its pre-Roman “Punic” or “African” character. For example, the existence of Sufetes at Thugga were assumed to be a preservation or direct adoption of the Carthaginian institution, in reality it appears to have been a local reinvention based on a distant memory with a significantly different set of functions and responsibilities (McCarty, 2017:412). Although it is true that the Pagus remodelled large parts of the forum and dismantled pre-existing temples (Fentress, 2021:965) there is evidence of a more complex religious relationship lurking beneath as well. For example, the people of Thugga continued to deposit stelae dedicated to Baal Hammon on the eastern side of the city, a highly localised ritual dating back possibly to the 3rd century BC (Gilhaus, 2021:170). Fewer than 40 of these contain any kind of written inscription, but 15 of these are inscribed with the names of Roman citizens in Latin, and several of these inscriptions lack cognomen. This implies that the dedicators were members of the Pagus which arrived at Thugga prior to the common adoption of cognomen by large portions of the population (Gilhaus, 2021:172). Rather than the local inhabitants placing a thin Roman veneer over pre-existing indigenous gods or abandoning local traditions entirely in favour of imposed Roman ones, it is clear that some members of the Pagus were participating in highly localised spirituality. Within this complex religious environment, already defined by dominant pre-existing chthonic traditions, the establishment of the Pagus could have plausibly catalysed a reinterpretation of the Roman ancestor gods, the Manes, producing a measurable impact on the region's commemorative culture.

# %% [markdown]
# ### Roman Commemoration and the Manes

# %% [markdown]
# The Manes were ancestor gods often thought to reside in the underworld (but in some traditions the sky too) who had a variety of powers that could be asserted upon the living. This ranged from assisting armies in battle, extending life and even witnessing oaths (King, 2020:8-63). There was a vast number of differing co-existing interpretations of the Manes and their associated powers, throughout the Roman world (King, 2020:62). There has been some debate as to whether they were invoked as the collective dead, but there are examples of individual ancestor worship too (King, 2020:35). Throughout the world the dead are often assigned power and agency (Pearson, 1993:203) and the Roman world was no exception to this. Death creates a crisis that is frequently understood within a cosmological framework, and resolved with ritual (Nilsson Stutz, 2015:4). The non-dogmatic nature of Greco-Roman spirituality makes it difficult to ascertain any universal characteristic of this cosmology or about the nature of the Manes beyond basic conceptions, such as the fact that they exist and possess some degree of power. Even this was not necessarily universal, with Epicureans questioning the value of worshipping the Manes altogether, albeit without questioning their existence (King, 2020:27). It is impossible to categorize and summarize all Roman attitudes towards death and belief in the afterlife (Hope, 1997:113), and there was almost unlimited room for variation.
#
# The Roman Calendar included two festivals relating to the dead. Lemuria, which was celebrated on the 9th, 11th and 13th of May and Parentalia, which was held 13th-21st of February (Hope, 2009:99). Lemuria was based around a ghostly midnight ritual in which an offering of black beans would be left for the Lemures - the malignant spirits of dead ancestors, before then being ritually exorcised from the home (Hope, 2009:99). It seems to have been reasonably common to conceive of the dead as potentially malignant (Hope, 2009:99). The division of the realm of the living from the realm of the dead appears to have been important, and upholding this division may have been a function of Lemuria. Like all other aspects of the Roman religion, conceptions varied. In addition to the Lemures there were also the Lares which were household ancestor gods of a less hostile nature, however sometimes it appears no distinction between Lares and Manes was made (King, 2020:63). Parentalia was a decidedly less ghostly ritual in which people would gather to remember deceased loved ones. Typically various offerings would be left by the grave, perhaps implying that the dead were to some extent capable of receiving sustenance (Hope, 2009:102). The actual significance of these festivals, and adherence to them is largely unknowable. The most detailed explanation for these festivals was produced by Ovid writing under the Augustan regime, thus he may have reinvented the significance of these festivals to appeal to the emperor’s emphasis on piety (Hope, 2009:99). In North Africa textual sources point to a differing interpretation of Parentalia in which a portion of a meal would be sacrificed to the dead. This ritual persisted into the Christian period as evidenced by clerical criticism of the practice (Rebillard, 2015). This is yet another example of a re-interpreted tradition in North Africa, perhaps related to a prior memory and understanding of ancestor deities.
#
# Although numerous literary works detail an afterlife and posit the existence of a hell-like realm called Tartarus and the correspondingly heaven-like kingdom of Elysium, most of these works have strong moral undercurrents, and the extent to which these stories were interpreted literally is uncertain (Hope, 2009:114). Complicating this is the fact that most epitaphs are short and lack explicit reference to the afterlife altogether (Hope, 2009:115).  Across the empire tombs rarely dealt with spiritual or philosophical concerns about the soul (Hope, 2009:37), instead it appears that the primary objective was individual memory and legacy, perhaps as a result of a tenuous belief in the afterlife (Hope, 2009:39). This typically related to a Roman conception of “immortality through memory” or praemium aeternitatis, with Pliny the Younger going as far as to state in a letter that pursuit of this eternal glory is the only good reason to practice virtue (Naccarato, 2025:242). However, the act of commemoration is inherently personal, and attitudes differed, with the Roman general Frontinius forbidding the erection of a monument to himself as he felt that someone’s memory would last only if deserved (Naccarato, 2025:243). Despite the lack of overt spiritual content in epitaphs, the opening of DM, short for Dis Manibus, appears to have become ubiquitous in the 1st century AD (Hope, 2009:115). Dis Manibus is an invocation of the Manes meaning “to the spirits of the departed”, it is uncertain to what extent this was reflective of belief, or perhaps it became an unquestioned convention (Hope, 2009:115). Once again, evidently a somewhat differing interpretation of this convention existed in North Africa, with the addition of an S for Sacrum “Dis Manibus Sacrum”. The cause for this addition remains unclear, although it is clearly a religious extension of the phrase, Sacrum meaning sacred or in full, “to the sacred spirits of the departed”. This perhaps, is another hint of a unique interpretation of the Manes, perhaps as a more spiritually significant force. At Thugga, “DMS” is totally dominant, “DM” appears just 8 times in a corpus of 2048 inscriptions, whereas “DMS” appears 1582 times. Across all of North Africa, DMS appears in 51% of inscriptions, in the Western provinces it appears in just 1% of all epitaphs, and in Rome 3% (Bennett, 2021:163). The preference for DMS is therefore not unique to Thugga, but it is especially dominant, even in the context of the wider region.
#
# It is not possible to divorce a funerary record from the cosmological or spiritual rationale that underpins it (Scarre, 2011:9). Although universal generalisations about death rituals are indefensible, they are typically built around a concept of liminality, in which ritual is a necessary component in transforming the individual from the world of the living to the world of the dead (Pearson, 1993:204). The spiritual is frequently actualised in material form (Pearson, 1993:203), an example of which can be the funerary record. It is therefore impossible to assess Thugga’s unusual commemorative record, without also assessing the potential spiritual rationale and context that may underpin it. First however, it is necessary to quantify to exactly what extent Thugga’s funerary record is unusual in the Roman world.

# %% [markdown]
# ## Digital Epigraphy and Methodology

# %% [markdown]
# Corpus linguistics is a quantitative methodology used within the field of linguistics, in which computer software is used to identify and count linguistic features, often with the objective of producing statistical models (McEnery and Wilson, 2001). It can be applied to many, if not all, aspects of language (Hardie, 2016:502), and therefore funerary epigraphy. It can be used to measure anything from the prevalence of certain formulae, broader patterns of collocation or to extract key relevant words and terms. A prerequisite for this, of course, is a dataset or corpus of machine-readable text. Producing such a dataset is logistically difficult and a significant constraint to conducting macro-level epigraphic research of this kind. The assembly of such a corpus usually requires painstaking manual labour, or the production of custom-built software tailored to the project (Hardie, 2016:510). This creates a technical barrier, however as I will go on to demonstrate this is now surmountable with the application of LLM coding. The development of corpus linguistics has been inextricably linked to the humanities. The first corpus was produced by the Jesuit priest and PhD student Roberto Busa whilst studying the writings of Thomas Aquinas, a project he finished in 1967 (McEnery and Wilson, 2001:20). Although it has been used in the study of knowledge production in the field of archaeology (Schwartz, 2024), large scale comparative studies of epigraphic data remain rare (Hermankova et al, 2022).

# %% [markdown]
# ## Quantitative and Digital Approaches in Epigraphy

# %% [markdown]
# The study of epigraphy has been historically dominated by detailed analysis and reading rather than broad comparative approaches, although this has started to change (Hermankova et al, 2022). Increasingly, the macro-scale study of epigraphy has been employed by archaeologists in the study of ancient demography, economics, migrations and socio-political organisation (Schiedel, 2007:3). These kinds of computational studies have largely been beyond the capabilities of any individual researcher (until recently) (Hermankova et al, 2022).  Despite this, the study of digital epigraphy has seen rapid growth in recent years, enabled by continued technological development (Hermankova et al, 2024). This rapid development however, is still constrained by several endemic issues, beyond the mere technical challenge of assembling a dataset. A significant limitation is the fact that the study of epigraphy, and ancient writing in general is decentralised across multiple academic disciplines (Hermankova et al, 2024). Epigraphers, archaeologists, linguists and classicists all employ differing methodological and theoretical frameworks. This impairs cross-discipline cooperation and knowledge transfer, something that is becoming increasingly recognised (De Santis and Rossi, 2018:13). A similar degree of disjointedness also persists on the technical side of the field, although now nearly 600,000 Latin inscriptions have been digitised (Hermankova et al, 2024), this has occurred across multiple databases, each employing separate terminologies, metadata practices, and classification systems (Hermankova et al, 2024). Finally recent rapid technological development has outpaced theoretical development in academia, with no standardised approach existing the research opportunities provided by this methodology have not been fully exploited (Bodel, 2024:2).
# More specifically, corpus linguistics remains largely restricted to the discipline of linguistics itself. Although a recent paper, published in March of 2026 assessed a corpus of 1650 late Roman inscriptions using corpus linguistics, it did so through an explicitly sociolinguistic, rather than archaeological lens. Specifically, to assess the reduction of AE to A in Latin inscriptions between the fourth and sixth centuries (Papini, 2026:112) something associated with the later evolution of Latin into a proto-Romance language. Bennett’s work employed a similar methodology, however largely depending on excel regex searches rather than corpus linguistic software, to identify common formula and assess other metrics such as average characters per inscription (Bennett, 2020:64). However, Bennett’s extremely broad approach meant that beyond calculating average inscription length and identifying prevalence of certain formula via regex searches, a more detailed analysis was not possible

# %% [markdown]
# ## Site Selection and Dating

# %% [markdown]
# ### Thugga

# %% [markdown]
# Thugga is central to this research, previously identified as a possessing an unusual epigraphic habit. Not only does it possess an extremely rich and well-preserved epigraphic record, but also an interesting and unusual cultural history. The date of the foundation of Thugga is unknown, but it was first recorded in the 4th century BCE when it was likely largely self-governing (Fentress and Dufton, 2022:191). It was not conquered violently, but shortly after the annexation of Numidian lands Roman settlers arrived, establishing a Pagus (Hitchner, 2002:598). This led to the development of an unusual dual administrative system defined by the existence of Sufetes (Fentress and Dufton, 2022:191) operating in parallel to the Roman magistrates and Pagus, for over two centuries (Hitchner, 2002:599).

# %% [markdown]
# ### Lambaesis

# %% [markdown]
# Lambaesis was first founded as a Roman military fort in 81 CE, and quickly also developed into a civilian town (Wilson, 2016). It would become the headquarters for Legio III Augusta, the only legion stationed in the region and one that would eventually be staffed largely by local recruits by the time of the second century (Faure, 2022:164). Lambaesis like Thugga has an excellent preservation record, with over 1500 individual funerary inscriptions digitised on EDCS. Additionally, it was host to a mix of cultural influences. Initially, the garrison comprised foreign soldiers alongside local civilians, many of whom intermarried. Over time it became host to soldiers of foreign descent born in Africa, as well as a large number of locals. The multi-ethnic nature of the Roman Army in North Africa “cannot be doubted” (Faure, 2022 p.164). This makes it an interesting candidate for corpus linguistic research, especially in comparison to Thugga, a city exposed to significantly different influences.

# %% [markdown]
# ### Rome

# %% [markdown]
# Rome was selected as a metropolitan “baseline”. I wished to compare the data from Lambaesis and Thugga, with a city from outside of North Africa. This was necessary to differentiate between trends local to North Africa, and the individual site. Rome was the most obvious choice for this, as an imperial capital with the most expansive epigraphic record in the Roman world, making it ideal for corpus design

# %% [markdown]
# ### Thuburiscium Bure and Uchi Maius

# %% [markdown]
# These are both smaller sites, located in close proximity to Thugga. They were selected as additional comparisons to assess whether patterns observed at Thugga extended to neighbouring communities as observed by Bennett, 2020:189.

# %% [markdown]
# ### Dating

# %% [markdown]
# Accurate dating is difficult, as even inscriptions with dating metadata typically consist of broad approximations rather than specific dates, sometimes spanning four centuries (Hansen, 2021: 142). An initial attempt to construct century-by-century corpora proved unworkable for this reason, as the resulting datasets were nearly identical. Site history is therefore used as a proxy for estimated date ranges. At Thugga urban space began contracting by the fourth century, and the surrounding rural landscape entered rapid decline by the seventh (Von Rummel, 2016: 109). The Thugga corpus is accordingly assigned a first-to-fourth century date range, with the caveat that funerary inscription production likely peaked alongside general construction activity in the second and early third centuries (Cilliers, 2016:88). Lambaesis follows a comparable trajectory, effectively collapsing by the fifth century, with parts of the urban area converted to grave use as early as 350 AD (Roskam, 1996: 47). Both North African corpora are therefore broadly chronologically analogous, consisting predominantly of early and middle imperial material. This estimate is extended to both Uchi Maius and Thiburiscium Bure, both located within 12km of Thugga. To ensure comparability, the Roman corpus was restricted to inscriptions dated between 1–400 AD, which the higher proportion of precisely dated Roman inscriptions makes possible.

# %% [markdown]
# ## EDCS CorpusBuilder

# %% [markdown]
# The assembly of these corpora required the creation of bespoke software - CorpusBuilder which is a custom Python tool built around a text normalisation script. It strips unnecessary EDCS metadata and eliminates author expansions identifiable by their appearance within () and <> brackets while preserving restored letters within []. It identifies 29 common abbreviations frequent in Latin funerary epigraphy (Elliot, 1998), capitalises all text, and converts U to V throughout. The program consists of 1,698 lines of code and can generate funerary corpora from 10 sites, all North African except Rome, using source data extracted from EDCS in March 2025. Corpus generation is controlled through a Tkinter GUI, through which the researcher selects the data source, number of inscriptions, date range, inclusion or exclusion of Greek texts, and a damage threshold of inscriptions with 3 eligible characters or fewer are excluded. After generation, the programs calculate several corpora statistics to give the user a basic overview, these include total tokens, inscriptions, average tokens per inscription and length filter. The output is a UTF-8 encoded .txt file suitable for direct import into corpus analysis software such as AntConc.
# Architecturally, CorpusBuilder is a single Python script (or, when compiled, a single executable) that must reside in a folder containing a data subfolder. Within data are .txt files named according to site (e.g. thugga.txt, lambaesis.txt, rome.txt), each containing the raw inscription data exported directly from EDCS in its original, unprocessed form.

# %%
if getattr(sys, "frozen", False):
BASE_DIR = Path(sys.executable).parent
else:
BASE_DIR = Path(__file__).resolve().parent
DATA_FOLDER = BASE_DIR / "data"
SNAPSHOT_ROOT = DATA_FOLDER / "snapshots"
# Out:
#   Cell In[1], line 2
#     BASE_DIR = Path(sys.executable).parent
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# There is a dataset alias system that matches the source.txt file with clean GUI labels. This system assigns a short site code to each acceptable site name due to some variation that can appear on EDCS. For example, uchi_maius, uchimaius, and uchi-maius are recognised and assigned UM. Alternatively, Thugga and Dougga are both recognized as the same and assigned “T”. so

# %%
_DATASET_CODE_ALIASES = {
    "A":  ["ammaedra", "ammaedara"],
    "BR": ["bulla_regio", "bullaregio", "bulla-regio", "bulla regio"],
    "L":  ["lambaesis"],
    "T":  ["thugga", "dougga"],
    "ALL": ["*"],
    ...
}
DATASET_DISPLAY_NAMES = {
    "T":  "Thugga",
    ...
}

# %% [markdown]
# Additionally there is the option to combine all datasets as source for corpus generation, in which case the alias becomes ALL. It is possible to selectively combine datasets, in which case the alias includes both site codes, presented in alphabetical order separated with +, ensuring the same combination of sites always produces an identical, deterministic prefix regardless of selection order — a property the reproducibility system discussed later depends on. It is impossible to combine "ALL" with any other dataset, as this would be redundant.

# %%
def resolve_dataset_code_to_files(code: str, all_files: List[Path]) -> List[Path]:
    ...
    if code == "ALL":
        return list(all_files)
    if "+" in code:
        sub_codes = [c.strip() for c in code.split("+") if c.strip()]
        if "ALL" in sub_codes:
            raise ValueError("'ALL' cannot be combined with other dataset codes.")
        out: List[Path] = []
        for c in sub_codes:
            out.extend(resolve_dataset_code_to_files(c, all_files))
        return out
    aliases = _DATASET_CODE_ALIASES.get(code)

# %% [markdown]
# A similar system, but in the “reverse” direction exists to assign an alias to each dataset on startup. This means that the addition of future sites must be assigned an alias to function.

# %%
def infer_dataset_code_from_filename(filename: str) -> str:
    stem = _norm_stem(Path(filename).stem)
    for code, aliases in _DATASET_CODE_ALIASES.items():
        ...

# %% [markdown]
# One of the programs core functions is text cleaning and normalisation, a necessity to accurately restore inscriptions as to how they appear in stone. One of the first operations to this aim is the delineation of the raw .txt file into its constituent inscriptions accurately. It does so by reading the file and searching for EDCS-ID: which accompanies every inscription, and uses this to separate inscriptions from one another.

# %%
def split_into_blocks(lines: List[str]) -> List[Tuple[str, List[str]]]:

# %% [markdown]
# After this is completed it begins normalisation operations. This  includes stripping most EDCS metadata, such as findspot, author, province, editor ect. It removes all expansions identified as within () and <> editorial mark ups. Restored letters within [] are preserved, U becomes V and then a preset list of 29 commonly recognised abbreviations into single tokens. This is to prevent splintering of single abbreviations such as DMS into D, M , S which would artificially inflate token count and hinder any kind of analysis.

# %%
ABBREVIATION_PATTERNS = {
    r"\bD\s+M\s+S\b": "DMS",
    r"\bH\s+S\s+E\b": "HSE",
    ...  # 29 total patterns
}

def clean_inscription_lines(lines: List[str], greek_only: bool = False) -> str:
    ...
    line = re.sub(r"\([^)]*\)", "", original)   # strip author expansions
    line = re.sub(r"<[^>]*>", "", line)          # strip editorial markup
    line = line.replace("[", "").replace("]", "") # strip restored-letter brackets
    line = re.sub(r"[uU]", "V", line)             # normalise U to V
    ...
    for pattern, repl in ABBREVIATION_PATTERNS.items():
        line = re.sub(pattern, repl, line)

# %% [markdown]
# The core system that ties this together appends user inputs in this process. For example, by pre-selecting a date filter which is inferred by EDCS dating metadata, or be excluding Greek language inscriptions, or a eliminating those that do not adhere to a preset character length.

# %%
def build_corpus_core(source_files, n, seed_canon, greek_filter,
                       date_enabled, start_year, end_year,
                       exclude_fragments, len_min, len_max
                       ) -> Tuple[List[Tuple[str, str]], str, str]:
    ...
    for p in source_files:
        lines = p.read_text(...).splitlines()
        blocks = split_into_blocks(lines)
        for edcs_id_line, raw_lines in blocks:
            # Greek filter
            # Date filter
            cleaned = clean_inscription_lines(raw_lines, ...)
            # Fragment filter
            # Length filter
            ...
    ds_fp = dataset_fingerprint(source_files)
    subset_pairs = deterministic_select(inscriptions, n, seed_canon, ds_fp)
    rendered = [f"****\nEDCS-ID: {eid}\n{text}\n" for (eid, text) in subset_pairs]
    corpus_text = "\n".join(rendered)

# %% [markdown]
# All of these preferences are implemented during the generation process, for example the inclusion or exclusion of Greek:

# %%
GREEK_RANGE_RE = re.compile(r"[\u0370-\u03FF\u1F00-\u1FFF]")
...
contains_greek = bool(GREEK_RANGE_RE.search(original_text))
if greek_filter == "Exclude" and contains_greek:
    continue
if greek_filter == "Greek Only" and not contains_greek:
    continue

# %% [markdown]
# The date filter operates in a similar fashion.

# %%
DATE_RE = re.compile(r"dating:\s*(-?\d+)\s+to\s+(-?\d+)", re.I)
...
if date_enabled:
    m = DATE_RE.search(original_text)
    if not m:
        continue
    ds, de = map(int, m.groups())
    if de < start_year or ds > end_year:
        continue

# %% [markdown]
# As does the Fragment filter:

# %%
if exclude_fragments and count_nonspace_chars(cleaned) <= 3:
    continue

# %% [markdown]
# And the length filter

# %%
def passes_length_filter(text, len_min, len_max) -> bool:
    if len_min is None and len_max is None:
        return True
    n = count_nonspace_chars(text)
    if len_min is not None and n < len_min:
        return False
    if len_max is not None and n > len_max:
        return False
    return True

# %% [markdown]
# A final non-user facing system exists to delete duplicate inscriptions, this is especially useful when combining datasets, as EDCS can on occasion compile the same inscription into several regions/towns if close by.

# %%
bare_id = normalize_edcs_id(edcs_id_line)
if bare_id in seen_ids:
    continue
seen_ids.add(bare_id)

# %% [raw]
# All inscriptions must pass through these preset filters before been added to the “candidate pool”. This is because corpora generation is ultimately regulated by a deterministic system, a prerequisite for having a reproducible key system. Every time a corpus is generated twelve random bytes are generated, and encoded into Base32, a 32-character alphabet (A-Z) and (2-7). This produces a random string of 20 characters which forms the core component of the key. This however is not alone sufficient enough to reproduce the corpus. Settings used during initial generation must also be encoded in the key. To this aim the aforementioned site alias, becomes the key prefix and other setting appended to the end. The result is a key that looks like this:

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "An overview of EDCS CorpusBuilders key system"
            ]
        }
    }
}
display(Image("media/KeyKey.png"), metadata=metadata)

# %% [markdown]
# Once the filters specified by the key have been applied and non-conforming inscriptions eliminated from the candidate pool, the SHA-256 calculation is performed. SHA-256 assigns a unique hash first to the dataset as a whole, then to every individual EDCS ID within it. The final input to this calculation is the generated key itself:
#                                Score = SHA256(key | dataset hash | EDCS ID)
# Entering a key therefore amounts to supplying identical values to this equation, which necessarily yields identical results, and consequently the same ranking of inscriptions, and thus the same reproduced corpus, both in terms of which inscriptions are selected and the order in which they appear. SHA-256 is designed as a cryptographic tool and was selected primarily due its extremely low collision rate (virtually 0 or to be specific 1 in 2²⁵⁶) when compared to non-cryptographic hash alternatives. An added bonus is that every corpus generation ultimately consists of randomly selected inscriptions with the caveat of them confirming to filtering selection.

# %%
def _sha256_file(p: Path) -> str:
    h = hashlib.sha256()
    with p.open("rb") as f:
        for chunk in iter(lambda: f.read(1 << 16), b""):
            h.update(chunk)
    return h.hexdigest()


def dataset_fingerprint(files: List[Path]) -> str:
    pairs = []
    for p in sorted([Path(x) for x in files], key=lambda x: x.name.lower()):
        try:
            pairs.append((p.name, _sha256_file(p)))
        except Exception:
            pairs.append((p.name, "ERROR"))
    h = hashlib.sha256()
    for name, sh in pairs:
        h.update(name.encode("utf-8"))
        h.update(b"\0")
        h.update(sh.encode("ascii", errors="ignore"))
        h.update(b"\n")
    return h.hexdigest()


def deterministic_select(
    inscriptions: List[Tuple[str, str]],
    n: int,
    seed_canon: str,
    ds_fp: str,
) -> List[Tuple[str, str]]:
    if n <= 0:
        return []

    def score(eid: str) -> bytes:
        msg = f"{seed_canon}|{ds_fp}|{eid}".encode("utf-8")
        return hashlib.sha256(msg).digest()

    ranked = sorted(inscriptions, key=lambda it: (score(it[0]), it[0]))
    return ranked[:n]

# %% [markdown]
# After corpus generation the user will be prompted to back up the corpus. If the user chooses to do so a second copy of the corpus will be stored in the data folder, this also includes generation metadata, such as a manifest.JSON file which includes all the settings used in initial corpus generation. This is redundancy should either the key, or the corpus itself be lost. As settings are adjusted, the key field updates in real time to reflect the current configuration, using a placeholder in the seed position until a corpus is built and a real seed is generated

# %% [markdown]
# ### Program Limitations
# When using two corpora from the same site, there is a chance that they will contain overlapping inscriptions. This not necessarily a limitation but should be noted. The only way to confirm overlap would be to manually cross reference EDCS: IDs. This would be time consuming if done manually, but with the help of a corpus-linguistic tool/software it can be completed relatively easily. A further limitation is that it is not possible to modify the parameters of an already-generated corpus while retaining the same key. Any change to a filter or setting after generation triggers the invalidation system, which clears the stored seed and assigns a new one on the next build. Reproducing a prior corpus with altered settings would therefore require manually reconstructing the key token with the desired parameters. This process while straightforward given the key's readable format, is not currently supported within the GUI itself.

# %% [markdown]
# ### Corpus Specifications
# In total 8 corpora were generated for this research, containing a combined 8,002 individual inscriptions, of which at least 6454 are unique. These included a large corpus from each site, which consists of all digitised inscriptions from Thugga and Lambaesis from EDCS (as of March 2025). These corpora were generated without a dating filter, primarily due to the rarity of dating metadata. The Roman corpus was generated with a dating filter (1-400AD), this was possible due abundance of dated inscriptions from Rome. These large corpora were used for macro-analysis, and for assessing lexical diversity. Smaller sub-corpora for Lambaesis and Rome were also generated to facilitate more granular analyses. A final corpus of shorter inscriptions from Rome was generated with a length filter of 0-35 characters, to determine if there was perhaps an economic dimension to variation observed between sites. Finally two more corpora were generated from towns neighbouring Thugga, to see if trends observed at Thugga extended to nearby communities.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Overview of each corpus"
            ]
        }
    }
}
display(Image("media/Corpus_Overview.png"), metadata=metadata)

# %% [markdown]
# ### Dating
# Accurate dating is difficult, as even inscriptions with dating metadata typically consist of broad approximations rather than specific dates, sometimes spanning four centuries (Hansen, 2021: 142). An initial attempt to construct century-by-century corpora proved unworkable for this reason, as the resulting datasets were nearly identical. Site history is therefore used as a proxy for estimated date ranges. At Thugga urban space began contracting by the fourth century, and by the seventh (Von Rummel, 2016: 109). The Thugga corpus is accordingly assigned a first-to-fourth century date range, with the caveat that funerary inscription production likely peaked alongside general construction activity in the second and early third centuries (Cilliers, 2016:88). Lambaesis follows a comparable trajectory, effectively collapsing by the fifth century, with parts of the urban area converted to grave use as early as 350 AD (Roskam, 1996: 47). Both North African corpora are therefore broadly chronologically analogous, consisting predominantly of early and middle imperial material. This estimate is extended to both Uchi Maius and Thiburiscium Bure, both located within 12km of Thugga. To ensure comparability, the Roman corpus was restricted to inscriptions dated between 1–400 AD, which the higher proportion of precisely dated Roman inscriptions makes possible.

# %% [markdown]
# ## Measuring Standardisation and Formulaic Patterning
# Measuring lexical diversity is frequently an objective of corpus-linguistic study (Tweedie and Baayen, 1998:323), which makes it particularly applicable to Thugga and the assessment of its seemingly highly constrained funerary epigraphy. There are multiple metrics that are used to assess a corpus’s standardisation. One of the most frequently used and mathematically simple ones is the type-token ratio (TTR). The TTR of each site is calculated by dividing the total number of types (unique words/abbreviations) by total number of tokens (words/abbreviations). This identifies the percentage of unique vocabulary that appears in each corpus. It is important to note that funerary epigraphy is inherently more constrained than typical linguistic datasets that consist of free-flowing text. It is also important to note that TTR values are suppressed in proportion to corpus size (Tweedie and Baayen, 1998:323). TTR can be summarized as a measurement of the proportion of unique words, and as new words cannot be introduced faster than total number of words larger corpora will always return lower TTR scores. In this instance Rome, as the largest corpus will return a TTR score that is disproportionately lower (appearing more standardized) than either Lambaesis or Thugga. This is referred to as the corpus size effect.
# A solution to this is the implementation of Herdan’s C TTR, a logarithmic modification to the TTR calculation that accounts for the corpus size effect. Ultimately it measures the rate at which new words (types) are added in proportion to the total number of words (tokens), rather than just measuring the unique vocabulary of a corpus. It was implemented as a further verification of TTR results. The average number of tokens per inscription were also calculated, to complement the findings of Bennett who calculated the average number of characters per inscription. Additionally a custom index was devised, the formulaic concentration index or FCI which measures the proportion of the entire corpus that consists of the top 10 most frequently appearing terms. This is an empirical way to measure a corpus’s reliance on specific limited formulae, rather than a general metric of standardization.
# Template maps were constructed to map the dominant formulaic structure of Thugga's funerary epigraphy. Using AntConc's KWIC tool, the frequency with which inscriptions followed each successive formulaic element was calculated as a relative percentage, with each branch using the preceding term as its denominator. For example, of the 87.27% of inscriptions beginning with DMS, 100% follow this with the name of the deceased. The resulting trees map the corpus's dominant formulaic patterns rather than accounting for every inscription. KWIC searches were additionally used to identify key terms and abbreviations relating to social and professional roles, including familial identifiers, which were exported and compared in tabular form. All structural analysis was conducted on the two smaller dated corpora from Thugga and Lambaesis. The Lambaesis corpus has a smaller date range (100-200CE). This was necessary to reduce its size, as it was otherwise almost impossible to construct a lexical distribution tree due to the diversity of terms and order. To extract personal identifiers AntConc’s tag system was used, searching for a pre-loaded list of 63 relevant terms and abbreviations in both corpora.

# %% [markdown]
# ### Limitations
# Dating uncertainty is the most significant limitation. Site history implies the corpora largely consist of first-to-fourth century inscriptions, but a narrower objective date range cannot be assigned, making it difficult to detect chronological variation within the datasets. A small number of inscriptions likely fall outside this range entirely, and while Thugga and Lambaesis appear to have followed similar trajectories of decline, the corpora cannot be confirmed as precisely chronologically equivalent. The 2 smaller datasets from Lambaesis and Thugga are of differing date ranges albeit they overlap, Lambaesis occupying a much narrower range of 100-200 CE compared to Thugga’s 1-400 CE, a necessary constraint for creating a lexical distribution tree at Lambaesis altogether.
# Abbreviation tokenisation posed a methodological challenge. Without intervention, AntConc tokenises abbreviations such as DM or D.M into single-letter tokens, inflating the total token count and rendering output uninterpretable. CorpusBuilder was designed with a list of common funerary abbreviations to be merged into single lexical units, initially comprising 12 entries. However, single-letter tokens continued to appear among the top ten most frequent terms at each site, with Rome a notable outlier. Expanding the list from 12 to 29 abbreviations produced only a 0.78% reduction in Rome's token count (310 tokens), indicating that the majority of single-letter tokens at Rome are genuine initials rather than split abbreviations, and were not significantly distorting the results.
# It must also be noted that EDCS inscription counts do not correspond exactly to individual epitaphs. EDCS counts individual stones, several of which contain multiple epitaphs typically of family members. This is why the Thugga dated corpus of 233 inscriptions actually contains 275 individual epitaphs. This discrepancy does not critically affect the analysis but should be noted.

# %% [markdown]
# # Results
# All standardization metrics reveal a consistent hierarchy of uniformity. Thugga demonstrates the most restricted vocabulary, followed by Lambaesis, with Rome exhibiting the greatest lexical diversity. This same pattern also appears in the much smaller, dated corpora but with smaller calculated difference.
# The dated corpora (which consist of just a combined 347 inscriptions) were used for more granular analysis. Alongside this, terms pertaining to professional and social roles were extracted using the KWIC function in Antconc. These corpora were also used as the basis for the creation of lexical distribution trees.
# The undated corpora (which consist of a combined 6128 individual inscriptions) were used for macro-analysis and the quantitative measurement of linguistic features and standardization between the three sites. This included the extraction of the 100 most frequent terms appearing in each site, a necessity to perform the Formulaic Concentration Index calculations. The total number of lexical units (tokens) and number of unique lexical units (types) were also extracted and used to calculate TTR and Herdans C scores.

# %% [markdown]
# ## Average Epitaph Length
# The average length of inscriptions was calculated by dividing the total number of tokens (words) per corpus (N)  (measured in Antconc as total frequency) by the total number of inscriptions in each corpus .
#
# Average Inscription Length =	(Tokens(N))/(Inscriptions(I))
# Results:
# Thugga:  (20628(N))/(2048(I)) = 10.0  Lambaesis: (25009(N))/(1585(I)) = 15.8   Rome: (39664(N))/(2000(I)) =19.8
#
# Thugga emerges as a significant outlier, Roman epitaphs average nearly twice as long (98% longer), while inscriptions from Lambaesis exceed Thugga's by 57.7%. Interestingly the gap between Lambaesis and Rome is less significant, than that of Thugga and Lambaesis despite geographic proximity to each other. These differences, detected between such large corpora allude to structural differences in commemorative practice.

# %% [markdown]
# ## Type Token Ratio
# TTR score was calculated by extracting unique lexical types per corpus, measured in antconc as “entries” (V), which was then divided by tokens (N). TTR is a standard measure of lexical diversity, however TTR values inversely correlate to corpus size, meaning larger corpora will always appear to be less lexically diverse when compared to smaller ones (Lisson et al, 2018). As we are comparing corpora of different sizes, Rome will record a disproportionately lower TTR score due to corpus size effects, rather than real standardization (Mitchell, 2014). Equally Lambaesis as the smallest corpus will yield a comparatively higher TTR score. These results were presented to three decimal places, as smaller mathematical differences are representative of significant real-world differences.
#
# TTR=  (Types (V))/(Tokens (N) )
# Results
# Thugga: (2650 (V))/(20628(N)) = 0.128. Lambaesis: (3661 (V))/(25009 (N)) = 0.146. Rome (7077(V))/(39664(N)) = 0.178
#
# Despite mechanical compression of TTR scores, site ranking remains unchanged, however Lambaesis is closer to Thugga then Rome. Rome is a significant outlier. As the largest corpus Rome experiences the most mechanical suppression of its TTR score, despite this it maintains a 0.05 (39%) and 0.032 (22%) point higher score than Thugga and Lambaesis respectively. These results require qualification, as comparing corpora of differing sizes is inherently problematic because of artificial score compression. Regardless, the hierarchy first observed in average inscription length is preserved.

# %% [markdown]
# ## Herdans C
# A modification to the TTR calculation was devised by the linguist Gustav Herdan to empirically account for TTR score compression, referred to as Herdans C. (Mitchell, 2014). It does this by introducing the logarithmic function to the TTR calculation, measuring the number of unique words added to the corpus in proportion to the number of total words. In short, it measures lexical diversity by measuring how quickly vocabulary grows as corpus size increases.
#
# Herdan C=   log⁡〖(V)〗/log⁡〖(N)〗
# Results
# Thugga: ((log)2650 )/((log)20628 ) = 0.79. Lambaesis: ((log)3661 )/((log)25009 ) = 0.81. Rome:  (log)7077/(log)39664 = 0.83.
#
#
# Even when accounting for corpus size, the same pattern of results appear. These results demonstrate that this pattern is representative of structural differences in funerary epigraphy between sites, rather than artificial compression of TTR values. However this time, the gap between sites is roughly even with a 0.02 gap between each site. Lambaesis produces longer epitaphs than Thugga (15.8 vs 10 tokens) but achieves this with somewhat constrained vocabulary.

# %% [markdown]
# ## Formulaic Concentration Index
# To further quantify standardization by site, it was necessary to create a custom index – the Formulaic Concentration Index (FCI). This measures the proportion of the whole corpus that consists of the top ten most frequent lexical types (words).
# FCI=  (Top 10 Tokens(Nt))/(Total Tokens(N) )
#
# Results
# Thugga: (5559 (Nt))/(20628 (N)) = 27 Lambaesis: (4732 (Nt))/(25009 (N)) = 18.9 Rome (5450(Nt))/(39664(N)) = 13.7
#
# The FCI index results yield the most striking evidence yet for hyperstandardisation at Thugga. 27% of the entire corpus at Thugga consists of just 10 lexical units. This degree of formulaic concentration far exceeds both Lambaesis (18.9%) and Rome (13.7%). Lambaesis once again occupies an intermediate position, perhaps pointing to some shared commemorative preferences that are far more pronounced at Thugga.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "The Top 10 most frequent terms from Thugga, Lambaesis and Rome"
            ]
        }
    }
}
display(Image("media/Corpus Overview.png"), metadata=metadata)

# %% [markdown]
# The FCI index results yield the most striking evidence yet for hyperstandardisation at Thugga. 27% of the entire corpus at Thugga consists of just 10 lexical units. This degree of formulaic concentration far exceeds both Lambaesis (18.9%) and Rome (13.7%). Lambaesis once again occupies an intermediate position, perhaps pointing to some shared commemorative preferences that are far more pronounced at Thugga.

# %% [markdown]
# ## Template Map
# The prior metrics established strong evidence for differing commemorative practices and formulaic rigidity at Thugga. To map this template precisely, two dated corpora from Thugga (n=233) and Lambaesis (n=93), were analysed using the lexical distribution tree method described in section 3.3.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Template map outlining dominant epitpah construction"
            ]
        }
    }
}
display(Image("media/TemplateTree.png"), metadata=metadata)

# %% [markdown]
# Virtually all complete inscriptions beginning with DMS (87.27% of the corpus) follow a consistent formula. The left and central branches are functionally identical, both proceeding from the name of the deceased to a statement of piety and age at death, the left branch using PVA (Pius Vixit Annis, "lived piously for X years"), the central branch rendering this in full or partial form (e.g. Pia/Pius Vixit Annis, PV Annis). The third branch, while omitting the piety reference, maintains an equivalent structure: name → Vixit Annis/VA → age at death. The vast majority of inscriptions across all branches terminate with HSE (Hic Situs Est, "here he/she lies"). Comparison with the Lambaesis corpus reveals a stark contrast.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Template tree outlining dominant epitpah construction at Lambaesis"
            ]
        }
    }
}
display(Image("media/TemplateMapL.png"), metadata=metadata)

# %% [markdown]
# Unlike Thugga, Lambaesis lacks any coherent template. Word order and word type vary significantly, with dominant terms appearing by plurality rather than consistent sequence, producing a web-like rather than linear structure. Individual inscriptions invoke the same tokens in differing orders, and the corpus diverges rapidly into high-entropy territory referring to the divergence of the Corpus into many terms that appear in low frequencies There is substantially greater emphasis on individual secular commemoration, further inflated by the frequent inclusion of details about the dedicator something almost entirely absent at Thugga. The majority of these references are related to military roles, unsurprising given that it was the legionary fortress for II Augusta.

# %% [markdown]
# # Discussion
# When compared with Rome and Lambaesis, the funerary epigraphy of Thugga is highly unusual. Not only does it have a highly consistent and committed preference for short, standardized inscriptions, it does so by repeatedly invoking the same formulae. Additionally, any reference to the deceased’s professional identity (and largely social identity too) is almost entirely excluded. This is highly unusual, as the celebration of one’s conventional success was frequently a focus of Roman funerary epigraphy, the objective of which was to affirm personal memory (Hope, 2009:39). Military cemeteries are typically more standardized, as soldiers tend to reiterate a collective unit or military identity in death (Hope, 1997:116). This likely explains the disparity between Lambaesis and Rome. This, however, implies that Thugga is even more of an outlier, with both a lack of  individual epitaph variation (although it does exist) and a near total absence of any reference to the secular life of the deceased to the extent it is statistically significantly more standardized than a predominantly military site.
# Bennett argues that Thugga’s uniformity (and similar profiles found in nearby cities) may be the result of travelling stone masons with a reliance on copy books potentially mass-producing pre-cut stelae (Bennett 2020:192-211). This may be logistically true to some extent, it is not, however, a causal explanation. If we are to presume that Thugga’s epigraphic habit is a result of commercial convenience, we are also presuming that Thuggans did not care enough to try and commission more individual epitaphs and passively accepted what the market offered. In a somewhat similar vein to this, Shaw when referencing both the unusual degree of formulaic standardization in North Africa, and the absence of familial references argued that this was simply the result of poverty and space saving (Shaw, 1984:463). Both these arguments eliminate the agency of Roman North Africans and treats them as passive subjects of circumstance. I would argue that this view is not supported by the available evidence.

# %% [markdown]
# ## Commercial Necessity and Mass Production?
# To assess the likelihood of the mass production hypothesis, a closer analysis is required. Although Bennett correctly noted the unusual dominance of certain formulae, and it is even possible to map out a dominant template, individual variation still exists, and the order in which these terms are presented is not always concrete. For example, although PVA (Pia Vixit Annis) is highly dominant, occurring 1047 times in a corpus of 2048 stones, P V AN, P V ANNIS, P VIX AN, PIVS VIXIT ANNIS, PIA VA, PIA VIXIT also appear and some variation of this is what the other half of the corpus predominantly consists of.

# %% [markdown]
# ### Non-Exhaustive list of alternatives to PVA
# | Formula | Number of Occurrences |
# |---------|:---------------------:|
# | P V AN | 77 |
# | PIA VIXIT | 74 |
# | PIVS VIXIT ANNIS | 61 |
# | PIA VA | 22 |
# | P V ANNIS | 20 |
# | PIA VIXIT AN | 10 |
# | PIA VIX AN | 8 |

# %% [markdown]
# Despite the fact that all these formulae are functionally almost identical, each one being some variation of “lived piously for x years”, the way in which this is invoked can differ significantly, and sometimes by as little as a single or a few letters (VIX vs VIXIT for example). Additionally, even of those that appear with PVA, there is often still some level of variation, for instance a number follow HSE with other abbreviations e.g “OTBQTTLS”. This diversity points to voluntary adherence rather than mass-production. It should also be noted, that as flagged by Bennett herself and as evidenced by multiple metrics assessed in this research, the preference for certain formula and standardization is not exclusive to Thugga (Bennett, 2020:156). This implies that we are not observing the result of pre-cut mass-produced stelae, but a deliberate commemorative preference that potentially existed throughout Africa Proconsularis but was strongest at Thugga and the immediate surrounding region.
# A more developed version of the commercial necessity hypothesis is that a differing preservation environment at Thugga has privileged the preservation of shorter inscriptions produced by people from a lower socio-economic background. This is a real possibility as Thugga’s rapid decline and relative remoteness meant that only limited amounts of spolia were taken from the site which was left predominantly in-situ. Perhaps the corpora differences can be explained by the destruction of similar inscriptions in Rome are simply less likely to survive extensive urban reuse. To test this hypothesis, a corpus of 2048 Roman inscriptions was generated with a length filter of 0-44 characters. This produced a corpus with an average length of 9.5, even shorter than Thugga’s 9.7. Herdens C and FCI scores were calculated.
#
# Herdens C =(3157(Types))/(19573(Tokens)) = 0.81
#
# Remarkably even though the average inscription length is shorter than that of Thugga in this corpus, it still exhibits higher levels of lexical diversity, with the score now near identical to Lambaesis. This is also reflected by the short Corpus’s FCI score.
#
# FCI =(2,249(Nt))/(19573(Tokens)) = 11
#
# The short Rome corpus exhibits extremely limited reliance its top 10 most frequently used terms, reducing from the other Roman corpuses score of 13. Regardless this is further confirmation that we are observing the product of cultural preference rather than one reflective of economic convenience or a preservation bias. In the short Roman corpus, DMS appears just 10 times, and pietas, and PVA none.

# %% [markdown]
# ## Ritual Adherence Beyond Secular Social Memory
# Is it possible then, that the arrival of the Pagus to a region with pre-existing chthonic traditions was a catalyst for a reinterpretation of the Roman Manes, perhaps as powerful and influential spirits that had to be commemorated correctly, rather than as individuals? The secular qualities of the deceased become irrelevant if the objective is not immortal memory and individual legacy, but ritual correctness. If the Manes of Thugga were unusually powerful and therefore ritually demanding, perhaps they had to be addressed correctly and rigidly, and this explains the heavy repeated use of formulae, and the almost omnipresent inclusion of reference to the deceased’s piety. To investigate the corpus further I extracted all longer (60-character) funerary inscriptions that abandoned the typical formula altogether. There were only 28 inscriptions of this kind (just 1.37% of the corpus), some of which were highly revealing.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Your caption or source description here"
            ]
        }
    }
}
display(Image("media/Picture45.png"), metadata=metadata)

# %% [markdown]
# The first half of this inscription adheres perfectly to Thugga's dominant formula opening with DMS, certifying piety and age, closing with H.S.E. The second half is frankly bizarre. The dedicator directly addresses the deceased, attributing the monument's belated erection to the craftsman. That this explanation was considered worth carving in stone indicates the delay caused the dedicator sufficient anxiety to publicly petition his deceased mother with an excuse. Further attention should be paid to the specific word choice employed. Veneranda means to worship/venerate and in the gerundive case, it explicitly implies religious obligation to his mother. This kind of petition only makes sense if the Manes are conceived as powerful, and potentially malevolent entities if ritual obligations are not upheld, a conception not alien in the Roman world (Hope, 2009:103) In this case the obligation is evidently correct and timely commemoration. This inscription almost explicitly reveals a portion of the cosmological rationale that underpins the funerary epigraphy of Thugga and is not the only one that does so.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Your caption or source description here"
            ]
        }
    }
}
display(Image("media/edcs16800151.png"), metadata=metadata)

# %% [markdown]
# This inscription is similar in character, although avoids attributing blame to any external actor. It follows the typical formula of funerary epigraphy at Thugga, with the second half acknowledging a delay in commemoration. It is interesting to note that the dedicator describes it as an altar “aram” rather than a tomb, indicating a clear ritual function to the grave itself. This ritual function may relate to the omnipresent inclusion of Sacrum in DMS. The dedicator both acknowledges his lateness but also makes it clear that he has fulfilled his obligation, absolving himself of guilt. What was considered “late” for commemoration at Thugga is unknowable but is evidently a ritual violation of some kind. As these petitions appear to be directed at the dead, it appears the Manes are conceived of as capable of granting reprieve for such violations. Equally noteworthy, is the fact that these petitions are inscribed directly into the commemorative stone, perhaps implying a direct relationship between the monument and the Manes, to some extent as a medium of communication. In some traditions, the Manes or a “spirit” more generally was considered to reside within the tomb itself, and failure to erect one would result in a vengeful wandering spirit (Hope, 2009:102). As discussed in 2.2 in North Africa meals would often be ritually sacrificed as the gravesite, pointing to a clear ritual function to the tomb, some interpretation of which likely existed at Thugga. A common theme amongst other inscriptions that totally abandon the typical formula of Thugga, is that they were commissioned in advance by the deceased themselves. Probably one of the most significant outliers of this is a poem inscribed onto a mausoleum.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "EDCS:16201258"
            ]
        }
    }
}
display(Image("media/edcs16201258.png"), metadata=metadata)

# %% [markdown]
# This is most remarkable, employing a range of rhetorical devices of a high cultural register. Although it appears to depart entirely from the typical formula, there remain several notable parallels. Firstly, the dedicator explicitly states the piety of both himself and his wife. More so using ad satiem – “to satiety/fullness” as pietas is an obligation rather than a quality. Additionally, it finishes with a direct petition to the “ruler of Avernus” Dominator Averni, to grant him peaceful rest amongst the Manes. With Avernus being the entrance to the underworld (Clark, 1996:261), this is likely addressed to Pluto. This is a highly formal petition, with the dedicator refusing to call the god by name, and instead by his title. Additionally, it is worth noting what is absent. It is reasonable to assume, that the dedicator of this inscription was educated, and wealthy, due to both the length of the inscription and his impressive cultural repertoire. Despite this, there is absolutely no reference to his secular life achievements, profession, or his wealth, instead he only affirms his completion of what he considers to be his earthly duty, before formally petitioning Pluto for acceptance amongst the Manes. Functionally speaking, this inscription is not as significant of an outlier as it appears to be at first glance. Additionally, though more speculative, it is possible that “discite sic vestros merito sancire parentes” or "learn thus to duly honour your parents" is potentially a religious invocation, encouraging the reader to uphold their own spiritual obligations to their deceased ancestors. The use of Sancire prior to parentes may hint at this, Sancire meaning to make sacred, to ratify or to consecrate. This conception may also be supported by the prior noted dominance of FIL and other markers of descent in Thugga’s funerary epigraphy. Roman inheritance law typically stipulated who was responsible for worshiping the Manes of the deceased, making lineage important in determining who owes ritual obligation to whom (King, 2022:9). Of the other 26 inscriptions that abandon the typical formula altogether, nearly all are highly emotive, or commissioned in advance by the deceased.

# %%
from IPython.display import Image
metadata = {
    "jdh": {
        "module": "object",
        "object": {
            "type": "image",
            "source": [
                "Your caption or source description here"
            ]
        }
    }
}
display(Image("media/edcsx2.png"), metadata=metadata)

# %% [markdown]
# This indicates that the people of Thugga had agency and could depart from typical commemorative conventions if they wished, although evidently rarely did. A particularly striking example is EDCS:16201258 supstitui natum qui colat semper Larem or “I have raised up/appointed a son whose purpose is to worship the Lares forever”. This directly implies that the continued worship of the Lares is the core purpose of raising his son (Grimwade, personal communication, 2026).
# It is typically thought that lasting memory was the core objective of commemoration across the Roman world (Hope, 2009:39). Epitaphs rarely dealt with spiritual or philosophical concerns and instead frequently sought to capture the identity of the individual (Hope, 1997:113 and 2009:37). This, however, does not appear to be true at Thugga. Further contradicting this conception is the existence of near identical gravestones, of different people with the same name at Thugga.

# %% [markdown]
# | EDCS ID | Inscription Text |
# |---------|-------------------|
# | EDCS-16800152 | DMS Q MODIVS FELIX PVA LXXV HSE |
# | EDCS-25601552 | DMS Q MODIVS FELIX PVA LXXXV HSE |

# %% [markdown]
# These two epitaphs would be identical if not for the differing age of death (differentiated by a single X). These individuals were almost certainly related. Although neither inscription has been dated, and these men may have lived in differing time periods, in a small town like Thugga it is highly likely at least one was aware of the other. Despite this, absolutely no attempt is made to preserve the individual memory of either. Outside of the select few who knew the exact age of death, it is impossible to differentiate between these epitaphs. There are other similar instances.

# %% [markdown]
# | EDCS ID | Inscription Text |
# |---------|-------------------|
# | EDCS-16201416 | DMS IVLIA VICTORIA PVA XXX |
# | EDCS-16201327 | DMS IVLIA VICTORIA PVA XXXV HS |

# %% [markdown]
# Euergetism was another avenue by which the affluent could secure lasting memory. This desire to leave a legacy inspired public projects and civic donations across the empire, usually accompanied by a lengthy inscription honouring the dedicator (Hope, 2009:34). Thugga was no stranger to euergetism, with the notable Gabinni family alone responsible for constructing 4 of the city’s temples (Fentress, 2021:698). However, the city’s non-religious public buildings lack dedications altogether, with the benefactors choosing to remain anonymous (Fentress, 2021:969), something which is extremely unusual in the Roman world (Hope, 2009:34). The temples that are accompanied by dedications, appear to be semi-private in nature, typically accessed by inconspicuous entrances from the street (Fentress, 2021:969), unusually they are scattered through residential areas, and appear to have been deeply personal to the dedicators (Fentress, 2021:969).
#
# The large number of these temples implies a highly religious character of the town, with 25 temples of this style identified thus far (Fentress, 2021:698). Acts of religious euergetism may have been essential in accessing prestigious priesthoods (Bertolazzi, 2016:86), reference to these priesthoods are some of the only personal identifiers that exist in Thugga’s funerary epigraphy (as soon on p.34). In a highly religious town, such priesthoods may have represented the apex of public life. Notably at Thugga, women were both eligible for such roles and actively participated in religious euergetism often holding powerful priesthoods (Bertolazzi, 2016:105). In the 3rd century the amount of money spent by women on such projects is almost equal to that of men (Bertolazzi, 2016:104). This may all be conducive to an atypical value system, which places little to no emphasis on individual legacy and identity after death.
#
# Based on the available lines of evidence it appears that the overwhelming formulaic standardisation of Thugga's funerary corpus possibly reflects a localised reinterpretation of the Manes as an active divine community potentially with agency over the admission of the dead into the Manes. Central to this interpretation is pietas, a concept worth examining carefully, as it is by far the most dominant and almost the only recurring trait across the corpus. Rather than simply representing religious devotion as the modern word piety does, pietas refers to adherence and participation in reciprocal social and religious relationships, often conceived spiritually as a collective relationship between an entire community and the gods (King, 2020:45). As evidenced explicitly by EDCS-16201258, pietas at Thugga appears to have been a worldly obligation  pietatem implevimus, "we fulfilled pietas," treating it as a measurable duty discharged to capacity rather than a personal quality  and its inclusion on nearly every epitaph implies that completion of this duty may have been a prerequisite to joining the Manes after death.
#
# In this interpretation, the epigraphic monument functioned not just as an individual commemoration but as a component of a ritual, with the almost universal inclusion of pius/pia vixit certifying the deceased's diligent completion of pietas as a qualification for admission. In this context standardisation was functionally necessary because correct deployment of formulae was part of this ritual. Beyond this it is difficult to construct a fully evidence-based hypothesis. Whether the dedicator of EDCS-69200511 was attempting to placate the potentially vengeful spirit of his mother, or to guarantee her acceptance into the Manes by explaining away his belated commemoration, (perhaps both) is ultimately unknowable. What the epigraphic evidence does establish is that at Thugga, correct and timely commemoration was understood as an obligation with real spiritual consequences, a conclusion supported by the formulaic uniformity of the corpus, the emphasis on pietas, and the anxiety of those late in commemoration.

# %% [markdown]
# ## Belief Clusters
# When discussing variation in interpretation of the Manes King coins the term “belief clusters” to explain reoccurring general overlaps in some conceptions pertaining to a deity (such as the Manes), albeit not universally (King, 2020:87). It is possible then, that the epigraphic habit of Thugga is a preservation of one of these belief clusters. This does not require a radical redefinition of the Manes. Conceptions of the Manes as powerful and requiring ritually specific worship existed throughout the Roman world (King, 2020:10). A localist interpretation of the Roman Manes built around a conception of ritual correctness related to the completion of obligatory pietas at Thugga is entirely coherent in a region with pre-existing chthonic traditions and a religious world defined by non-dogmatism. The Manes appear to have been widely considered to be “minor” deities with belief in the afterlife tenuous (Hope, 2009:39). In the highly religious town of Thugga (Fentress and Dufton, 2022:193), it appears that this was not the case, to the extent that ritual correctness and adherence was valued above secular individual legacy and memory.

# %% [markdown]
# ## Future Research
# Based on the number of temples per capita Bennett correctly notes that Thugga’s epigraphic habit is not unique.  To confirm this the FCI, average inscription length and most frequent terms for these nearby sites were assessed. Due to the small size of the corpora assessment of TTR and Herdan’s C TTR is made redundant by the corpus size affect.
#
#
# The template dominant at Thugga extends to both Uchi Maius, and Thiburisicum Bure, with all three sites being significant outliers when compared to Lambaesis and Rome. Uchi Maius is located just 12km west of Thugga, and Thiburisicum Bure just 4.7km north-east. Of the three Uchi Maius is the most divergent due to the limited presence of PVA (19 times) in favour of P/PIVS/PIA vix/it. Thurburisicum Bure is almost indistinguishable from Thugga, although the latter maintains a stronger preference for PVA, which appears just 54 times or in 28% of total inscriptions compared to 51.1% at Thugga. These measurable differences in deployment of PVA further contradict the copybook hypothesis, and perhaps point to independent stone masons operating in each site.
#
# Figure 20: Thugga and nearby sites (Åhlfeldt, 2013).
# It should also be noted that EDCS does not always organise data by specific site, particularly smaller sites. For instance, inscriptions listed as being from the nearby town of Numluli also appear in the Thugga corpus. It includes inscriptions from the town’s broader hinterland and is therefore to some extent reflective of the wider region rather than exclusively the city. It is possible than that the epigraphic habit of Thugga and the surrounding region is the product of a “belief cluster” preserved in stone, a specific local interpretation of the Manes that incentivised unique and highly formulaic commemorative preferences that dominate the immediate region’s funerary epigraphy so thoroughly. A topic of future research could be to see if this belief cluster exists and what its geographic range is.
# What is clear however, is that the application of corpus-linguistic methodology to the study of epigraphy is viable. The only explicit kind of limitation in this research is the data itself. This methodology could be applied to any kind of ancient writing, from any time period. Future analysis could include an aggregate of curse tablets from separate sites, monumental inscriptions and beyond. Corpus-linguistic software can be used to “datamine” ancient sources of text, for key terms or phrases and their context in a convenient and accurate manner. With the potential of significant time reductions enabling researchers to dramatically increase the scale and scope of study, even with limited resources. Equally the implementation of AI tools for coding related tasks, makes it now possible to automate large parts of menial research related work, such as the assembly of large datasets.
